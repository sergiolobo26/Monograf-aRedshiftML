# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Test de Algorítmos de ML

# %%
ls
# Out:
# batch_job-8.sh             krr_results.out   results_model2.tar.gz
# batch_job.sh               krr_template.py   results_modelo/
# GALAXY-BGS.ipynb           krr_test.out      results_modelo_svr/
# GALAXY-LRG.ipynb           krr_train.out     results_modelo_svr.tar.gz
# krr_grid_search_modelo.py  LRG_tar           svr_grid_search_modelo.py
# krr_grid_search.py         LRG_true          svr_grid_search.py
# krr_grid_search-test1.py   Magnitud_Z.ipynb  test_ML_algortims_for_BGS.ipynb
# krr_model_results/         nohup.out
# krr_njobs1.txt             __pycache__/

# %%
pwd
# Out:
# '/home/sd.lobo251/Desktop/git/RedShiftML_/Python'

# %% [markdown]
# ## Resultados evaluación de performance

# %%
#time vectors:

#n_jobs = 1
# ppn=32, mem=64
njobs1_fit_mean = [0.6563,   4.5574,   98.2674,  340.9284]
njobs1_fit_error = [0.3758,     0.1468,   0.0954,  0.3033]

njobs1_pred_mean = [4.7517e-04,   7.5332e-03,   1.6545e-01,   5.5307e-01]
njobs1_pred_error = [6.8729e-05,   3.7210e-04,   1.5883e-03,   1.5807e-02]

#n_jobs = 1
# ppn=32, mem=32
njobs12_fit_mean = [ 0.5941 ,   4.0394,   92.8291,  357.6147 ]
njobs12_fit_error = [  0.3375,  0.0361 , 0.0382,  0.1608]

njobs12_pred_mean = [ 3.9721e-04 ,  5.9602e-03  , 1.4817e-01  , 5.7699e-01]
njobs12_pred_error = [ 1.7643e-05 ,  1.2327e-04 ,  3.9560e-04 ,  3.8981e-03]

# -------------------------------------------------------------------------------

#n_jobs = 4
# ppn=8, mem=16
njobs4_fit_mean = [37.3983,   412.7043,   6849.4955,  15406.7071]
njobs4_fit_error = [21.4944,     65.0584,   3830.2076,  11210.5692]

njobs4_pred_mean = [5.9589e-04,   3.4594e-02,   2.9752e+01,   5.3781e+01]
njobs4_pred_error = [5.5555e-05,   1.7173e-03,   2.4003e+01,   4.3107e+01]

#n_jobs = 4
# ppn=32, mem=32

njobs42_fit_mean = [ 0.7678 ,   5.7375 ,  51.4291,  146.9329]
njobs42_fit_error = [ 0.0366 , 0.3944 , 0.4265,  1.0651]

njobs42_pred_mean = [ 0.0011,  0.0084,  0.2269 , 0.6987]
njobs42_pred_error = [ 0.0002 , 0.0008,  0.0123,  0.013 ]

# -------------------------------------------------------------------------------
#n_jobs = 8
# ppn=16 ,mem= 32
njobs81_fit_mean=  [   5.0733,  153.1527,  490.3082, 670.5144]
njobs81_fit_error=  [  0.037,    2.1263,   5.0282,  10.7809] 

njobs81_pred_mean = [ 0.0005,  0.0146,  0.195,   0.5065]
njobs81_pred_error = [  4.4724e-05,   8.7791e-04,   9.1646e-03,   6.3661e-03] 
    
#n_jobs = 8
# ppn= 32, mem= 32
njobs82_fit_mean = [   5.9411,  134.1912,  300.6281,  415.2503]
njobs82_fit_error = [ 0.0397,  1.1395,  2.6022,  1.5424] 

njobs82_pred_mean = [ 0.0014,  0.0165,  0.193,   0.595 ]
njobs82_pred_error = [ 0.0007,  0.004,   0.0114,  0.0038] 
    
#n_jobs = 8
# ppn= 8, mem=16
njobs83_fit_mean = [  322.3028,   339.5963,  3534.0626,  2979.7312]
njobs83_fit_error = [  254.2151,    19.1855,  1905.8418,  1404.8172] 

njobs83_pred_mean = [  5.5281e-04,   7.6867e-02,   5.9666e+01,   6.7151e-01]
njobs83_pred_error = [  9.5670e-05,   1.8453e-03 ,  4.8466e+01 ,  3.1150e-02] 

#n_jobs = 8
# ppn= 16, mem=64

njobs84_fit_mean =  [   5.1279,  159.4978 , 503.0066,  689.4906]
njobs84_fit_error =  [ 0.1651,  6.1825 , 1.4837,  1.5344] 

njobs84_pred_mean =   [ 0.0006,  0.0125,  0.2413,  0.6226]
njobs84_pred_error =   [  8.8792e-06,   2.5068e-03,   2.5919e-02,   7.8364e-02] 

#n_jobs = 8
# ppn= 32, mem=128

njobs85_fit_mean =  [  1.0019 ,  4.0952 , 30.2987 , 75.9758]
njobs85_fit_error =  [ 0.2778,  0.1544 , 0.3512 , 0.4184] 

njobs85_pred_mean =   [ 0.0007 , 0.0059 , 0.1107,  0.4376]
njobs85_pred_error =   [0.0001,  0.0007  ,0.0147  ,0.0182]
# -------------------------------------------------------------------------------
#n_jobs = 16
# ppn= 32, mem=32

njobs161_fit_mean =  [   300.7808,   1978.296 ,   4749.9376 , 10732.7107]
njobs161_fit_error = [  146.2924 , 1123.4129 , 1818.3769 , 3953.3885] 

njobs161_pred_mean =  [  6.9722e-04  , 1.0108e-02 ,  2.3376e-01 ,  7.4573e-01]
njobs161_pred_error =  [  1.6717e-05 ,  2.6070e-03,   1.0397e-02 ,  1.1032e-01] 
    
#n_jobs = 16
# ppn= 32, mem=128

njobs162_fit_mean = [ 0.9731,   4.5099,  25.3806,  66.0461  ]
njobs162_fit_error =  [ 0.5384,  0.0616,  0.1732,  0.3939  ] 

njobs162_pred_mean =  [ 4.6897e-04,   1.2616e-02 ,  2.1646e-01  , 6.2114e-01  ]
njobs162_pred_error =   [ 4.1433e-05,   4.5715e-03 ,  3.6269e-02  , 1.8564e-03 ] 
    
    
# -------------------------------------------------------------------------------


data_set = [100, 1000, 5000, 10000]

# %%
figure(figsize=(15, 12))
#errorbar( log10(data_set), njobs161_fit_mean, yerr= log10(njobs161_fit_error), fmt='--', markersize=2, ecolor='b', capthick=2)

errorbar( data_set, njobs83_fit_mean, yerr= njobs83_fit_error, fmt='-o', markersize=2, ecolor='m', capthick=2, color='m', label='ppn: 8 - mem: 16 Gb')
errorbar( data_set, njobs84_fit_mean, yerr= njobs84_fit_error, fmt='-o', markersize=2, ecolor='b', capthick=2, color='b', label='ppn: 16 - mem: 64 Gb')
errorbar( data_set, njobs81_fit_mean, yerr= njobs81_fit_error, fmt='-o', markersize=2, ecolor='y', capthick=2, color='y', label='ppn: 16 - mem: 32 Gb')

errorbar( data_set, njobs82_fit_mean, yerr= njobs82_fit_error, fmt='-o', markersize=2, ecolor='r', capthick=2, color='r', label='ppn: 32 - mem: 32 Gb')

errorbar( data_set, njobs85_fit_mean, yerr= njobs85_fit_error, fmt='-o', markersize=2, ecolor='g', capthick=2, color='g', label='ppn: 32 - mem: 128 Gb')
yscale('log')
xscale('log')
grid(True, linestyle='--', which = 'both')
xlabel('Número de datos', fontsize='14')
ylabel('Tiempo [s]', fontsize='14')
tick_params(axis='both', which='major', labelsize=14)
legend()

# %%
figure(figsize=(15, 12))
#errorbar( log10(data_set), njobs161_fit_mean, yerr= log10(njobs161_fit_error), fmt='--', markersize=2, ecolor='b', capthick=2)
errorbar( data_set, njobs162_fit_mean, yerr= njobs162_fit_error, fmt='-o', markersize=2, ecolor='y', capthick=2, color='y', label='n_proc: 16 - mem: 128 Gb')

errorbar( data_set, njobs85_fit_mean, yerr= njobs85_fit_error, fmt='-o', markersize=2, ecolor='r', capthick=2, color='r', label='n_proc: 8 - mem: 128 Gb')
errorbar( data_set, njobs42_fit_mean, yerr= njobs42_fit_error, fmt='-o', markersize=2, ecolor='m', capthick=2, color='m', label='n_proc: 4 - mem: 32 Gb')
errorbar( data_set, njobs12_fit_mean, yerr= njobs12_fit_error, fmt='-o', markersize=2, ecolor='b', capthick=2, color='b', label='n_proc: 1 - mem: 32 Gb')
yscale('log')
xscale('log')
grid(True, linestyle='--', which = 'both')
xlabel('Número de datos', fontsize='14')
ylabel('Tiempo [s]', fontsize='14')
tick_params(axis='both', which='major', labelsize=14)
legend()

# %%
from sklearn.externals import joblib

# %% [markdown]
# # Modelo KRR - 100000 datos ------------------------------------------------------------------------------------------------------------------

# %%
krr10_model_0_test = loadtxt('krr_model-100000.480195.clustermaster.uniandes.edu.co/krr_model_0_test.txt', dtype = float)
krr10_model_1_test = loadtxt('krr_model-100000.480195.clustermaster.uniandes.edu.co/krr_model_1_test.txt', dtype = float)
krr10_model_2_test = loadtxt('krr_model-100000.480195.clustermaster.uniandes.edu.co/krr_model_2_test.txt', dtype = float)

krr10_model_0_train = loadtxt('krr_model-100000.480195.clustermaster.uniandes.edu.co/krr_model_0_train.txt', dtype = float)
krr10_model_1_train = loadtxt('krr_model-100000.480195.clustermaster.uniandes.edu.co/krr_model_1_train.txt', dtype = float)
krr10_model_2_train = loadtxt('krr_model-100000.480195.clustermaster.uniandes.edu.co/krr_model_2_train.txt', dtype = float)


print(krr10_model_2_test.shape)
print(krr10_model_2_train.shape)

krr10_model_train = stack((krr10_model_0_train, krr10_model_1_train, krr10_model_2_train))
krr10_model_test = stack((krr10_model_0_test, krr10_model_1_test, krr10_model_2_test))

print(krr10_model_train.shape)
print(krr10_model_test.shape)
# Out:
# (3, 20000)
# (3, 80000)
# (3, 3, 80000)
# (3, 3, 20000)

# %%
figure(figsize=(15,10), dpi=100)

for i in range(3):
    subplot(2,2,1+i)
    plot(x, x, '--')
    scatter(krr10_model_train[i, 2,:], krr10_model_train[i, 1,:], s=3, label= 'Original')
    scatter(krr10_model_train[i, 0,:], krr10_model_train[i, 1,:], s=3, label= 'Modelo')
    legend()
    xlabel('Z tar - Z pred', fontsize='12')
    ylabel('Z true', fontsize='12')
    
figure(figsize=(15,10), dpi=100)

for i in range(3):
    subplot(2,2,1+i)
    plot(x, x, '--')
    scatter(krr10_model_test[i, 2,:], krr10_model_test[i, 1,:], s=3, label= 'Original')
    scatter(krr10_model_test[i, 0,:], krr10_model_test[i, 1,:], s=3, label= 'Modelo')
    legend()
    xlabel('Z tar - Z pred', fontsize='12')
    ylabel('Z true', fontsize='12')

# %% [markdown]
# # Modelo SVR - 100000 datos ------------------------------------------------------------------------------------------------------------------------

# %%
svr_model_0_test = loadtxt('results_modelo_svr/svr_model-100000.480160.clustermaster.uniandes.edu.co/svr_model_0_test.txt', dtype = float)
svr_model_1_test = loadtxt('results_modelo_svr/svr_model-100000.480160.clustermaster.uniandes.edu.co/svr_model_1_test.txt', dtype = float)
svr_model_2_test = loadtxt('results_modelo_svr/svr_model-100000.480160.clustermaster.uniandes.edu.co/svr_model_2_test.txt', dtype = float)

svr_model_0_train = loadtxt('results_modelo_svr/svr_model-100000.480160.clustermaster.uniandes.edu.co/svr_model_0_train.txt', dtype = float)
svr_model_1_train = loadtxt('results_modelo_svr/svr_model-100000.480160.clustermaster.uniandes.edu.co/svr_model_1_train.txt', dtype = float)
svr_model_2_train = loadtxt('results_modelo_svr/svr_model-100000.480160.clustermaster.uniandes.edu.co/svr_model_2_train.txt', dtype = float)

# %%
print(svr_model_2_test.shape)
print(svr_model_2_train.shape)
# Out:
# (3, 20000)
# (3, 80000)

# %%
svr_model_train = stack((svr_model_0_train, svr_model_1_train, svr_model_2_train))
svr_model_test = stack((svr_model_0_test, svr_model_1_test, svr_model_2_test))

print(svr_model_train.shape)
print(svr_model_test.shape)
# Out:
# (3, 3, 80000)
# (3, 3, 20000)

# %%
figure(figsize=(15,10), dpi=100)

for i in range(3):
    subplot(2,2,1+i)
    plot(x, x, '--')
    scatter(svr_model_train[i, 2,:], svr_model_train[i, 1,:], s=3, label= 'Original')
    scatter(svr_model_train[i, 0,:], svr_model_train[i, 1,:], s=3, label= 'Modelo')
    legend()
    xlabel('Z tar - Z pred', fontsize='12')
    ylabel('Z true', fontsize='12')
    
figure(figsize=(15,10), dpi=100)

for i in range(3):
    subplot(2,2,1+i)
    plot(x, x, '--')
    scatter(svr_model_test[i, 2,:], svr_model_test[i, 1,:], s=3, label= 'Original')
    scatter(svr_model_test[i, 0,:], svr_model_test[i, 1,:], s=3, label= 'Modelo')
    legend()
    xlabel('Z tar - Z pred', fontsize='12')
    ylabel('Z true', fontsize='12')

# %% [markdown]
# # Modelo KRR - 50000 datos ------------------------------------------------------------------------------------------------------------------

# %%
kr_model_0 = loadtxt('results_modelo/krr_model-50000.480138.clustermaster.uniandes.edu.co/krr_model_0.txt', dtype = float)

# %%
kr_model_1 = loadtxt('results_modelo/krr_model-50000.480138.clustermaster.uniandes.edu.co/krr_model_1.txt', dtype = float)
kr_model_2 = loadtxt('results_modelo/krr_model-50000.480138.clustermaster.uniandes.edu.co/krr_model_2.txt', dtype = float)
kr_model_3 = loadtxt('results_modelo/krr_model-50000.480138.clustermaster.uniandes.edu.co/krr_model_3.txt', dtype = float)

# %%
print(kr_model_2.shape)
# Out:
# (3, 10000)

# %%
kr_model = stack((kr_model_0, kr_model_1, kr_model_2, kr_model_3))
print(kr_model.shape)
# Out:
# (4, 3, 10000)

# %%
figure(figsize=(15,10), dpi=100)

for i in range(4):
    subplot(2,2,1+i)
    plot(x, x, '--')
    scatter(kr_model[i, 2,:], kr_model[i, 1,:], s=3, label= 'Original')
    scatter(kr_model[i, 0,:], kr_model[i, 1,:], s=3, label= 'Modelo')
    legend()
    xlabel('Z tar - Z pred', fontsize='12')
    ylabel('Z true', fontsize='12')

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Carga de modelos -  Ensemble methods :

# %%
krr_model_2 = joblib.load('krr_model-100000.480195.clustermaster.uniandes.edu.co/krr_model_2.pkl')
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator KernelRidge from version 0.18.1 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
import krr_grid_search_modelo as kr
true_data_path = '/home/sd.lobo251/Documents/dc17b/BGS_files/BGS_true_file.fits'
tar_data_path = '/home/sd.lobo251/Documents/dc17b/BGS_files/BGS_tar_file.fits'
fluxes = kr.import_data(true_data_path, tar_data_path)
fluxes = fluxes[600000:620000]
X_train, X_test, y_train, y_test, Z_tar_train, Z_tar_test = kr.train_test_data(test_size=0.9, fluxes_array=fluxes, n_datos=len(fluxes), r_state= 0)
# Out:
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
len(X_test)
# Out:
# 18000

# %%
X_train, X_test = kr.Standard_scale_data(X_train, X_test)

# %%
y_true, y_pred = y_test, krr_model_2.predict(X_test)

# %%
figure(figsize=(15, 12))
scatter(Z_tar_test, y_test, s = 3)
scatter(y_pred, y_test, s = 3 )
plot(x, x)

# %%
krr_model_1 = joblib.load('results_modelo/krr_model-50000.480138.clustermaster.uniandes.edu.co/krr_model_1.pkl')
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator KernelRidge from version 0.18.1 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
import krr_grid_search_modelo as kr
true_data_path = '/home/sd.lobo251/Documents/dc17b/BGS_files/BGS_true_file.fits'
tar_data_path = '/home/sd.lobo251/Documents/dc17b/BGS_files/BGS_tar_file.fits'
fluxes = kr.import_data(true_data_path, tar_data_path)
fluxes = fluxes[:50000]
X_train, X_test, y_train, y_test, Z_tar_train, Z_tar_test = kr.train_test_data(test_size=0.9, fluxes_array=fluxes, n_datos=len(fluxes), r_state= 0)
# Out:
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
X_train, X_test = kr.Standard_scale_data(X_train, X_test)
y_true, y_pred = y_test, krr_model_1.predict(X_test)
figure(figsize=(15, 12))
scatter(Z_tar_test, y_test, s = 3)
scatter(y_pred, y_test, s = 3 )
plot(x, x)
