# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ls
# Out:
# GALAXY-BGS.ipynb    krr_test.out   Magnitud_Z.ipynb    untitled.txt
# GALAXY-LRG.ipynb    krr_train.out  nohup.out
# krr_grid_search.py  LRG_tar        svr_grid_search.py
# krr_results.out     LRG_true       Untitled.ipynb

# %%
import csv

# %%
krr_train = loadtxt('krr_train.out', dtype='float')
krr_test = loadtxt('krr_test.out', dtype='float')

# %%
scatter(krr_train[0,:], krr_train[1,:])

# %%
scatter(krr_train[2,:], krr_train[1,:])

# %%
scatter(krr_test[0,:], krr_test[1,:])

# %%
scatter(krr_test[2,:], krr_test[1,:])

# %%
from astropy.io import fits

# %%
from astropy.table import Table
t = Table.read('/home/sd.lobo251/Documents/dc17b/BGS_files/BGS_true_file.fits', hdu=1)

# %%
t = array(t['TARGETID', 'TRUEZ', 'MAG'])

# %%
g =t[0:10][['TRUEZ', 'MAG']]
g['TRUEZ']
# Out:
# array([0.27507246, 0.23326778, 0.16340064, 0.1365762 , 0.3257975 ,
#        0.4807059 , 0.1542689 , 0.3775699 , 0.1292585 , 0.35179138],
#       dtype=float32)

# %%
data.field('TARGETID')
# Out:
# array([288230376151711747, 288230376151711749, 288230376151711754, ...,
#        288230530766341284, 288230530766341290, 288230530766341293])
